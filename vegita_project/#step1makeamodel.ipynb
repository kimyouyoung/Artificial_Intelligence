# %% [markdown]
# ---------
# # 배추가격 예측 AI Project for 모인활
#
# Notes by kjune18@naver.com, Handong Global Univ.

# %% [markdown]
# ## 기대효과

# %% [markdown]
# - 선형 회귀까지만 공부한 사람도 실제로 기상청 등의 데이터에서 다양한 배추 가격 데이터를 수집하고 직접 활용하여 스스로 웹사이트까지 구축해볼 수 있다.
# - 결과적으로 사용자의 입력값에 따라 적당한 배추 가격을 예측해주는 모델을 만들고, 모델을 통해 결과를 보여줄 수 있다.

# %% [markdown]
# ## 포함되는 개념들

# %% [markdown]
# 1. 파이썬 and Tensorflow에서 학습된 모델을 저장하고 필요에 따라서 불러오는 기능
# 2. Flask Web Server & Mdbootstrap Design Framework

# %% [markdown]
# ## 1. 선형 회귀
#
# 선형 회귀는 통계학에서 종속 변수 $y$와 한 개 이상의 독립 변수 $x$와의 선형 상관 관계를 모델링하는 회귀분석 기법이다.
# 선형 회귀는 선형 예측 함수를 사용해 회귀식을 모델링하며, 알려지지 않은 파라미터는 데이터로부터 추정한다. 이렇게 만들어진 회귀식을 선형 모델이라고 한다.
#
# 선형 회귀는 여러 사용 사례가 있지만, 대개 아래와 같은 두 가지 분류 중 하나로 요약할 수 있다.
# - 값을 예측하는 것이 목적일 경우, 선형 회귀를 사용해 데이터에 적합한 예측 모형을 개발한다. 개발한 선형 회귀식을 사용해 $y$가 없는 $x$값에 대해 $y$를 예측하기 위해 사용할 수 있다.
#
#
# - 종속 변수 $y$와 이것과 연관된 독립 변수 $X_1$,  ...   ,$X_p$
# 가 존재하는 경우에, 선형 회귀 분석을 사용해 $X_j$와 $y$의 관계를 정량화할 수 있다.
#
#
# <img src = "https://upload.wikimedia.org/wikipedia/commons/b/be/Normdist_regression.png" width=300>
# <center>그림 1: 독립변수 1개와 종속변수 1개를 가진 선형 회귀의 예

# %% [markdown]
# ## 2. 데이터 수집

# %% [markdown]
# 우리나라 정부에서는 다양한 데이터를 무료로 제공해주고 있다. 그러나, 데이터를 제공하는 정책이 서로 다를 수 있기 때문에 데이터를 수집하는 방법에 있어서는 조금씩 다르게 활용할 필요가 있다.

# %% [markdown]
# ### 기상청 자료 이용하기

# %% [markdown]
# 1. 기상자료개방포털(기후통계분석)로 이동한다.
# 2. 먼저 기온분석으로 이동하여, 원하는 기간과 지역/지점을 선택하고 csv다운로드 버튼을 눌러 데이터를 얻도록 한다.
# 3. 다음으로 강수량분석으로 이동하여, 앞에서 받은 데이터와 동일한 기간, 동일한 지역/지점을 선택하고 csv다운로드 버튼을 통해 데이터를 얻도록 한다.

# %% [markdown]
# ### 농산물유통 자료 이용하기

# %% [markdown]
# 1. 농산물유통정보사이트로 이동한다.
# 2. 가격정보에서 채소류->배추를 선택하고, 품종과 등급은 전체로 하여 조회한다.
# 3. 데이터 저장버튼을 통해 데이터를 얻도록 한다.

# %% [markdown]
# ## 3. 데이터 정제

# %% [markdown]
# 처음 수집한 data는 인공지능이 인식하기 쉬운 형태는 아니다.
# 따라서 엑셀 내부의 data를 정제함으로써 인공지능이 인식하기 쉬운 형태로 만들어 줘야 한다.
# 특히 배추의 가격은 주말 등에는 측정되지 않는 점이 있고, 몇몇 일자에는 가격이 급상승하는 data가 있기 때문에 data의 정제가 반드시 필요하다.

# %% [markdown]
# 여기에서 사용할 변인은 평균온도, 최저온도, 최고온도, 강수량 총 4가지 변인을 사용하여 가격을 예측하도록 할 것이다.
# <img src = "https://t1.daumcdn.net/cfile/tistory/99D710465B7D9A8E18" width= 300>

# %% [markdown]
# 정제된 data 링크 https://github.com/kjune18/AI-for-All

# %% [markdown]
# ## 4. 모델 만들기

# %% [markdown]
# 다변인 선형 회귀는 모델에 영향을 미치는 변인이 여러 개 일때 사용하는 모델이다. 현재 우리의 데이터에서는 변인이 '평균온도', '최저온도', 최고온도', '강수량'이므로 이 모든 요인이 '가격'에 영향을 미친다고 감안해야 한다. 따라서 가중치(Weight)을 고려했을 때 다음과 같은 수식을 세울 수 있다.

# %% [markdown]
# $H(x_1, x_2, x_3, x_4) = x_1w_1 + x_2w_2 + x_3w_3 + x_4w_4$

# %% [markdown]
# 파이썬에서 Tensorflow 라이브러리를 활용해 다변인 선형 회귀 모델을 구현한다.

# %%
# 엑셀에서 data를 읽어온다.
# pandas library: excel data를 읽어올 수 있다.
import tensorflow.compat.v1 as tf
import numpy as np
from pandas.io.parsers import read_csv
tf.disable_v2_behavior()

model = tf.global_variables_initializer()   # model 초기화하기

data = read_csv('pricedata.csv', sep=',')  # csv파일 읽어오기

xy = np.array(data, dtype=np.float32)    # 행렬 형태로 저장하기

# %%
# 4개의 변인을 입력을 받는다.
x_data = xy[:, 1:-1]   # slicing x

# 가격 값을 입력 받는다.
y_data = xy[:, [-1]]   # slicing y

# %% [markdown]
# placeholder의 전달 파라미터는 다음과 같다.
#
# placeholder(
#     dtype,
#     shape=None,
#     name=None
# )
#
#
# - dtype : 데이터 타입을 의미하며 반드시 적어주어야 한다.
#
# - shape : 입력 데이터의 형태를 의미한다. 상수 값이 될 수도 있고 다차원 배열의 정보가 들어올 수도 있다. ( 디폴트 파라미터로 None 지정 )
#
# - name : 해당 placeholder의 이름을 부여하는 것으로 적지 않아도 된다.  ( 디폴트 파라미터로 None 지정 )
#
# 텐서플로우 random_normal():
# 0~1 사이의 정규확률분포 값을 생성해주는 함수.
# 원하는 shape 대로 만들어줌

# %%
# placeholder를 설정한다.

X = tf.placeholder(tf.float32, shape=[None, 4])  # 변인 4개
Y = tf.placeholder(tf.float32, shape=[None, 1])  # 변인 1개
W = tf.Variable(tf.random_normal([4, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %% [markdown]
# W(가중치) 값과 b(바이어스) 의 값을 지정해야 하는데 이는 학습을 위해 임의의 값 (아직 잘 모른다고 가정)을 던져준다.
#
# 텐서플로우에서는 W와 b에 해당하는 변수를 Variable 을 사용하여 나타낸다. 그리고 텐서 플로우가 알아서 이 값을 자동으로 조절해 줄 것이며 나중에 비용함수가 최소(minimize)가 되는 가중치와 바이어스 값으로 조정하게 된다.

# %%
# 가설을 설정한다.
hypothesis = tf.matmul(X, W) + b  # 행렬 곱 연산

# %%
# 비용함수를 설정한다.
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 최적화 함수를 설정한다. 여기선 GradientDescent(경사하강) 함수 사용
# 학습률 0.000005로 설정한 이유 - 되도록 짧은 시간에 정확한 결과 나오게 하기 위함
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
train = optimizer.minimize(cost)

# %%
# 세션을 생성한다.
sess = tf.Session()

# 글로벌 변수 초기화시킨다.
sess.run(tf.global_variables_initializer())

# %%
# 학습을 수행한다.
ephocs = 100000
for step in range(ephocs):
    costx, hypox, trainx = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실비용: ", costx)
        print("-배추 가격: ", hypox[0])
# Out:
# # 0  손실비용:  12590044.0
# -배추 가격:  [6.4905005]
# # 500  손실비용:  4186066.8
# -배추 가격:  [-271.80157]
# # 1000  손실비용:  3781604.2
# -배추 가격:  [37.508865]
# # 1500  손실비용:  3465491.5
# -배추 가격:  [319.33673]
# # 2000  손실비용:  3216756.2
# -배추 가격:  [569.74316]
# # 2500  손실비용:  3020594.8
# -배추 가격:  [792.2241]
# # 3000  손실비용:  2865666.5
# -배추 가격:  [989.9458]
# # 3500  손실비용:  2743182.0
# -배추 가격:  [1165.6997]
# # 4000  손실비용:  2646281.0
# -배추 가격:  [1321.9535]
# # 4500  손실비용:  2569577.8
# -배추 가격:  [1460.8909]
# # 5000  손실비용:  2508837.2
# -배추 가격:  [1584.4427]
# # 5500  손실비용:  2460717.5
# -배추 가격:  [1694.3239]
# # 6000  손실비용:  2422580.5
# -배추 가격:  [1792.0532]
# # 6500  손실비용:  2392340.8
# -배추 가격:  [1878.9796]
# # 7000  손실비용:  2368350.0
# -배추 가격:  [1956.3013]
# # 7500  손실비용:  2349304.0
# -배추 가격:  [2025.081]
# # 8000  손실비용:  2334171.0
# -배추 가격:  [2086.2654]
# # 8500  손실비용:  2322134.8
# -배추 가격:  [2140.6943]
# # 9000  손실비용:  2312549.8
# -배추 가격:  [2189.115]
# # 9500  손실비용:  2304903.5
# -배추 가격:  [2232.1917]
# # 10000  손실비용:  2298792.5
# -배추 가격:  [2270.5151]
# # 10500  손실비용:  2293896.8
# -배추 가격:  [2304.61]
# # 11000  손실비용:  2289962.0
# -배추 가격:  [2334.9436]
# # 11500  손실비용:  2286788.5
# -배추 가격:  [2361.9312]
# # 12000  손실비용:  2284217.2
# -배추 가격:  [2385.9421]
# # 12500  손실비용:  2282123.0
# -배추 가격:  [2407.3062]
# # 13000  손실비용:  2280406.0
# -배추 가격:  [2426.3142]
# # 13500  손실비용:  2278987.8
# -배추 가격:  [2443.2273]
# # 14000  손실비용:  2277805.8
# -배추 가격:  [2458.2761]
# # 14500  손실비용:  2276811.0
# -배추 가격:  [2471.6665]
# # 15000  손실비용:  2275964.5
# -배추 가격:  [2483.581]
# # 15500  손실비용:  2275235.2
# -배추 가격:  [2494.1838]
# # 16000  손실비용:  2274599.0
# -배추 가격:  [2503.6199]
# # 16500  손실비용:  2274036.2
# -배추 가격:  [2512.0166]
# # 17000  손실비용:  2273531.5
# -배추 가격:  [2519.4897]
# # 17500  손실비용:  2273072.8
# -배추 가격:  [2526.1401]
# # 18000  손실비용:  2272651.2
# -배추 가격:  [2532.059]
# # 18500  손실비용:  2272258.2
# -배추 가격:  [2537.3271]
# # 19000  손실비용:  2271888.5
# -배추 가격:  [2542.017]
# # 19500  손실비용:  2271537.0
# -배추 가격:  [2546.1917]
# # 20000  손실비용:  2271199.5
# -배추 가격:  [2549.9087]
# # 20500  손실비용:  2270873.8
# -배추 가격:  [2553.2183]
# # 21000  손실비용:  2270557.0
# -배추 가격:  [2556.164]
# # 21500  손실비용:  2270248.0
# -배추 가격:  [2558.7874]
# # 22000  손실비용:  2269944.2
# -배추 가격:  [2561.1243]
# # 22500  손실비용:  2269645.8
# -배추 가격:  [2563.2046]
# # 23000  손실비용:  2269350.8
# -배추 가격:  [2565.0623]
# # 23500  손실비용:  2269058.2
# -배추 가격:  [2566.7117]
# # 24000  손실비용:  2268769.0
# -배추 가격:  [2568.1816]
# # 24500  손실비용:  2268480.8
# -배추 가격:  [2569.493]
# # 25000  손실비용:  2268194.5
# -배추 가격:  [2570.6636]
# # 25500  손실비용:  2267909.5
# -배추 가격:  [2571.7065]
# # 26000  손실비용:  2267625.5
# -배추 가격:  [2572.639]
# # 26500  손실비용:  2267343.0
# -배추 가격:  [2573.4727]
# # 27000  손실비용:  2267060.8
# -배추 가격:  [2574.2102]
# # 27500  손실비용:  2266778.2
# -배추 가격:  [2574.8616]
# # 28000  손실비용:  2266497.8
# -배추 가격:  [2575.4636]
# # 28500  손실비용:  2266217.2
# -배추 가격:  [2575.9917]
# # 29000  손실비용:  2265937.0
# -배추 가격:  [2576.4824]
# # 29500  손실비용:  2265656.8
# -배추 가격:  [2576.9067]
# # 30000  손실비용:  2265377.0
# -배추 가격:  [2577.2869]
# # 30500  손실비용:  2265098.2
# -배추 가격:  [2577.6233]
# # 31000  손실비용:  2264819.8
# -배추 가격:  [2577.9465]
# # 31500  손실비용:  2264541.2
# -배추 가격:  [2578.1963]
# # 32000  손실비용:  2264262.2
# -배추 가격:  [2578.4373]
# # 32500  손실비용:  2263983.8
# -배추 가격:  [2578.6768]
# # 33000  손실비용:  2263705.5
# -배추 가격:  [2578.907]
# # 33500  손실비용:  2263427.5
# -배추 가격:  [2579.0994]
# # 34000  손실비용:  2263150.2
# -배추 가격:  [2579.2288]
# # 34500  손실비용:  2262873.2
# -배추 가격:  [2579.3567]
# # 35000  손실비용:  2262596.5
# -배추 가격:  [2579.4849]
# # 35500  손실비용:  2262319.8
# -배추 가격:  [2579.6125]
# # 36000  손실비용:  2262043.2
# -배추 가격:  [2579.7405]
# # 36500  손실비용:  2261766.8
# -배추 가격:  [2579.8682]
# # 37000  손실비용:  2261490.2
# -배추 가격:  [2579.9954]
# # 37500  손실비용:  2261214.0
# -배추 가격:  [2580.118]
# # 38000  손실비용:  2260938.2
# -배추 가격:  [2580.236]
# # 38500  손실비용:  2260662.0
# -배추 가격:  [2580.3076]
# # 39000  손실비용:  2260386.2
# -배추 가격:  [2580.345]
# # 39500  손실비용:  2260111.2
# -배추 가격:  [2580.3816]
# # 40000  손실비용:  2259837.0
# -배추 가격:  [2580.419]
# # 40500  손실비용:  2259562.2
# -배추 가격:  [2580.4539]
# # 41000  손실비용:  2259288.0
# -배추 가격:  [2580.487]
# # 41500  손실비용:  2259014.0
# -배추 가격:  [2580.5203]
# # 42000  손실비용:  2258739.8
# -배추 가격:  [2580.5537]
# # 42500  손실비용:  2258465.8
# -배추 가격:  [2580.5867]
# # 43000  손실비용:  2258191.8
# -배추 가격:  [2580.6204]
# # 43500  손실비용:  2257918.2
# -배추 가격:  [2580.6536]
# # 44000  손실비용:  2257644.8
# -배추 가격:  [2580.6868]
# # 44500  손실비용:  2257371.5
# -배추 가격:  [2580.721]
# # 45000  손실비용:  2257098.0
# -배추 가격:  [2580.7546]
# # 45500  손실비용:  2256824.8
# -배추 가격:  [2580.7886]
# # 46000  손실비용:  2256552.0
# -배추 가격:  [2580.8245]
# # 46500  손실비용:  2256279.0
# -배추 가격:  [2580.8613]
# # 47000  손실비용:  2256007.0
# -배추 가격:  [2580.8977]
# # 47500  손실비용:  2255735.5
# -배추 가격:  [2580.9329]
# # 48000  손실비용:  2255464.2
# -배추 가격:  [2580.971]
# # 48500  손실비용:  2255193.0
# -배추 가격:  [2581.009]
# # 49000  손실비용:  2254922.0
# -배추 가격:  [2581.0503]
# # 49500  손실비용:  2254651.0
# -배추 가격:  [2581.0928]
# # 50000  손실비용:  2254380.8
# -배추 가격:  [2581.1348]
# # 50500  손실비용:  2254109.8
# -배추 가격:  [2581.18]
# # 51000  손실비용:  2253839.2
# -배추 가격:  [2581.2256]
# # 51500  손실비용:  2253568.8
# -배추 가격:  [2581.272]
# # 52000  손실비용:  2253298.2
# -배추 가격:  [2581.3179]
# # 52500  손실비용:  2253028.5
# -배추 가격:  [2581.3665]
# # 53000  손실비용:  2252758.8
# -배추 가격:  [2581.4163]
# # 53500  손실비용:  2252488.2
# -배추 가격:  [2581.4666]
# # 54000  손실비용:  2252218.5
# -배추 가격:  [2581.5159]
# # 54500  손실비용:  2251950.2
# -배추 가격:  [2581.5603]
# # 55000  손실비용:  2251681.5
# -배추 가격:  [2581.6082]
# # 55500  손실비용:  2251413.2
# -배추 가격:  [2581.6565]
# # 56000  손실비용:  2251145.0
# -배추 가격:  [2581.7048]
# # 56500  손실비용:  2250877.0
# -배추 가격:  [2581.753]
# # 57000  손실비용:  2250608.8
# -배추 가격:  [2581.801]
# # 57500  손실비용:  2250341.0
# -배추 가격:  [2581.8494]
# # 58000  손실비용:  2250073.5
# -배추 가격:  [2581.8962]
# # 58500  손실비용:  2249806.5
# -배추 가격:  [2581.9392]
# # 59000  손실비용:  2249540.2
# -배추 가격:  [2581.9875]
# # 59500  손실비용:  2249274.2
# -배추 가격:  [2582.038]
# # 60000  손실비용:  2249008.2
# -배추 가격:  [2582.079]
# # 60500  손실비용:  2248742.2
# -배추 가격:  [2582.1128]
# # 61000  손실비용:  2248475.8
# -배추 가격:  [2582.146]
# # 61500  손실비용:  2248209.8
# -배추 가격:  [2582.1794]
# # 62000  손실비용:  2247944.2
# -배추 가격:  [2582.2131]
# # 62500  손실비용:  2247679.0
# -배추 가격:  [2582.2463]
# # 63000  손실비용:  2247413.2
# -배추 가격:  [2582.2803]
# # 63500  손실비용:  2247148.0
# -배추 가격:  [2582.3137]
# # 64000  손실비용:  2246882.8
# -배추 가격:  [2582.3643]
# # 64500  손실비용:  2246617.8
# -배추 가격:  [2582.4155]
# # 65000  손실비용:  2246352.2
# -배추 가격:  [2582.4695]
# # 65500  손실비용:  2246087.5
# -배추 가격:  [2582.5232]
# # 66000  손실비용:  2245822.5
# -배추 가격:  [2582.5764]
# # 66500  손실비용:  2245558.0
# -배추 가격:  [2582.627]
# # 67000  손실비용:  2245293.0
# -배추 가격:  [2582.678]
# # 67500  손실비용:  2245028.8
# -배추 가격:  [2582.7249]
# # 68000  손실비용:  2244764.2
# -배추 가격:  [2582.7705]
# # 68500  손실비용:  2244500.0
# -배추 가격:  [2582.8086]
# # 69000  손실비용:  2244235.8
# -배추 가격:  [2582.8418]
# # 69500  손실비용:  2243972.0
# -배추 가격:  [2582.876]
# # 70000  손실비용:  2243708.0
# -배추 가격:  [2582.9104]
# # 70500  손실비용:  2243444.2
# -배추 가격:  [2582.944]
# # 71000  손실비용:  2243180.8
# -배추 가격:  [2582.9778]
# # 71500  손실비용:  2242917.0
# -배추 가격:  [2583.0122]
# # 72000  손실비용:  2242653.8
# -배추 가격:  [2583.0464]
# # 72500  손실비용:  2242390.5
# -배추 가격:  [2583.0803]
# # 73000  손실비용:  2242129.8
# -배추 가격:  [2583.1033]
# # 73500  손실비용:  2241868.8
# -배추 가격:  [2583.1252]
# # 74000  손실비용:  2241608.0
# -배추 가격:  [2583.1475]
# # 74500  손실비용:  2241347.2
# -배추 가격:  [2583.1694]
# # 75000  손실비용:  2241087.0
# -배추 가격:  [2583.192]
# # 75500  손실비용:  2240826.8
# -배추 가격:  [2583.212]
# # 76000  손실비용:  2240566.5
# -배추 가격:  [2583.229]
# # 76500  손실비용:  2240306.8
# -배추 가격:  [2583.2456]
# # 77000  손실비용:  2240046.8
# -배추 가격:  [2583.2627]
# # 77500  손실비용:  2239786.8
# -배추 가격:  [2583.279]
# # 78000  손실비용:  2239527.2
# -배추 가격:  [2583.296]
# # 78500  손실비용:  2239267.2
# -배추 가격:  [2583.3127]
# # 79000  손실비용:  2239007.5
# -배추 가격:  [2583.3286]
# # 79500  손실비용:  2238748.2
# -배추 가격:  [2583.3398]
# # 80000  손실비용:  2238489.0
# -배추 가격:  [2583.3513]
# # 80500  손실비용:  2238230.0
# -배추 가격:  [2583.3628]
# # 81000  손실비용:  2237970.5
# -배추 가격:  [2583.3743]
# # 81500  손실비용:  2237711.8
# -배추 가격:  [2583.3855]
# # 82000  손실비용:  2237452.8
# -배추 가격:  [2583.397]
# # 82500  손실비용:  2237193.8
# -배추 가격:  [2583.4084]
# # 83000  손실비용:  2236934.8
# -배추 가격:  [2583.4202]
# # 83500  손실비용:  2236676.8
# -배추 가격:  [2583.4312]
# # 84000  손실비용:  2236417.8
# -배추 가격:  [2583.4407]
# # 84500  손실비용:  2236159.5
# -배추 가격:  [2583.4468]
# # 85000  손실비용:  2235901.2
# -배추 가격:  [2583.4531]
# # 85500  손실비용:  2235643.2
# -배추 가격:  [2583.4587]
# # 86000  손실비용:  2235385.2
# -배추 가격:  [2583.4648]
# # 86500  손실비용:  2235127.0
# -배추 가격:  [2583.4712]
# # 87000  손실비용:  2234869.2
# -배추 가격:  [2583.4854]
# # 87500  손실비용:  2234611.5
# -배추 가격:  [2583.5193]
# # 88000  손실비용:  2234354.0
# -배추 가격:  [2583.5535]
# # 88500  손실비용:  2234096.5
# -배추 가격:  [2583.5881]
# # 89000  손실비용:  2233839.2
# -배추 가격:  [2583.623]
# # 89500  손실비용:  2233582.2
# -배추 가격:  [2583.6572]
# # 90000  손실비용:  2233325.8
# -배추 가격:  [2583.6907]
# # 90500  손실비용:  2233071.2
# -배추 가격:  [2583.7244]
# # 91000  손실비용:  2232817.0
# -배추 가격:  [2583.7585]
# # 91500  손실비용:  2232562.8
# -배추 가격:  [2583.7925]
# # 92000  손실비용:  2232308.5
# -배추 가격:  [2583.8267]
# # 92500  손실비용:  2232054.8
# -배추 가격:  [2583.8608]
# # 93000  손실비용:  2231800.2
# -배추 가격:  [2583.8953]
# # 93500  손실비용:  2231546.5
# -배추 가격:  [2583.929]
# # 94000  손실비용:  2231292.8
# -배추 가격:  [2583.963]
# # 94500  손실비용:  2231039.0
# -배추 가격:  [2583.997]
# # 95000  손실비용:  2230785.5
# -배추 가격:  [2584.0305]
# # 95500  손실비용:  2230532.2
# -배추 가격:  [2584.065]
# # 96000  손실비용:  2230279.0
# -배추 가격:  [2584.0999]
# # 96500  손실비용:  2230025.8
# -배추 가격:  [2584.1343]
# # 97000  손실비용:  2229773.0
# -배추 가격:  [2584.1692]
# # 97500  손실비용:  2229520.0
# -배추 가격:  [2584.2031]
# # 98000  손실비용:  2229267.0
# -배추 가격:  [2584.2375]
# # 98500  손실비용:  2229014.2
# -배추 가격:  [2584.2722]
# # 99000  손실비용:  2228762.0
# -배추 가격:  [2584.3074]
# # 99500  손실비용:  2228509.5
# -배추 가격:  [2584.3423]

# %%
# 학습된 모델을 저장한다.
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt") #tensorflow로 학습시킨 딥러닝 모델을 저장하는 방법, 학습된 모델의 variable을 저장.
print("학습된 모델을 저장했습니다.")
# Out:
# 학습된 모델을 저장했습니다.

# %% [markdown]
# - 학습모델을 저장하는 이유
#
# 만약 학습 모델을 저장하지 않고 사용자로부터 배추 가격 예측 요청(Request)이 발생할 때마다 매 번 학습을 해서 결과를 돌려준다면 시간이 오래 걸리고 많은 리소스가 소모 될 것이다.
#
#   따라서 오프라인(Offline)에서 주기적으로 데이터를 이용해 학습을 진행한 뒤에, 그 결과를 저장해서 서버에서는 실시간 요청에 따라 이미 저장된 학습 모델로 배추 가격을 예측하는 것이 효율적이다.

# %% [markdown]
# ## 참고자료

# %% [markdown]
# 1. 선형회귀 위키백과(https://ko.wikipedia.org/wiki/%EC%84%A0%ED%98%95_%ED%9A%8C%EA%B7%80)
# 1. 안경잡이개발자
# https://ndb796.tistory.com/124
# 1. 텐서플로우 기본 문법
# https://gdyoon.tistory.com/8
# https://gdyoon.tistory.com/5
# https://zetawiki.com/wiki/%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C%EC%9A%B0_random_normal()
